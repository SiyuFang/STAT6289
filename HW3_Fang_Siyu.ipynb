# %% [markdown]
# <a href="https://colab.research.google.com/github/SiyuFang/STAT6289/blob/master/HW3_Fang_Siyu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Visualize the original result
# ## Load the data

# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping

path= 'https://raw.githubusercontent.com/SiyuFang/STAT6289/master/TSLA.csv'
df = pd.read_csv(path,error_bad_lines=False)
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2015-07-09  51.816002  52.590000  51.358002  51.584000  51.584000  16670500
# 1  2015-07-10  52.444000  52.599998  51.563999  51.830002  51.830002  13054500
# 2  2015-07-13  52.450001  52.509998  51.209999  52.431999  52.431999  14801500
# 3  2015-07-14  52.419998  53.198002  52.102001  53.130001  53.130001   9538000
# 4  2015-07-15  53.348000  53.498001  52.416000  52.627998  52.627998  10108000

# %% [markdown]
# ## Split the data into training and test sets

# %%
training_set = df.iloc[:800, 1:2].values
test_set = df.iloc[800:, 1:2].values

# %% [markdown]
# ## Lag1

# %%
# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(60, 800):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
print(X_train.shape)
#(740, 60, 1)
# Out:
# (740, 60, 1)

# %% [markdown]
# ## Build the model

# %%
model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0744
# Epoch 2/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0168
# Epoch 3/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0126
# Epoch 4/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0122
# Epoch 5/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0126
# Epoch 6/100
# 24/24 [==============================] - 3s 126ms/step - loss: 0.0142
# Epoch 7/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0119
# Epoch 8/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0124
# Epoch 9/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0115
# Epoch 10/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0105
# Epoch 11/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0094
# Epoch 12/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0098
# Epoch 13/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0093
# Epoch 14/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0085
# Epoch 15/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0085
# Epoch 16/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0088
# Epoch 17/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0084
# Epoch 18/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0081
# Epoch 19/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0069
# Epoch 20/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0081
# Epoch 21/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0076
# Epoch 22/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0072
# Epoch 23/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0077
# Epoch 24/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0074
# Epoch 25/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0065
# Epoch 26/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0065
# Epoch 27/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0069
# Epoch 28/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0069
# Epoch 29/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0072
# Epoch 30/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0055
# Epoch 31/100
# 24/24 [==============================] - 3s 127ms/step - loss: 0.0057
# Epoch 32/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0065
# Epoch 33/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0064
# Epoch 34/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0054
# Epoch 35/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0063
# Epoch 36/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0059
# Epoch 37/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0057
# Epoch 38/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0053
# Epoch 39/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0047
# Epoch 40/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0050
# Epoch 41/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0050
# Epoch 42/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0055
# Epoch 43/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0051
# Epoch 44/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0055
# Epoch 45/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0050
# Epoch 46/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0049
# Epoch 47/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0051
# Epoch 48/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0050
# Epoch 49/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0051
# Epoch 50/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0044
# Epoch 51/100
# 24/24 [==============================] - 3s 126ms/step - loss: 0.0046
# Epoch 52/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.0048
# Epoch 53/100
# 24/24 [==============================] - 4s 148ms/step - loss: 0.0042
# Epoch 54/100
# 24/24 [==============================] - 3s 127ms/step - loss: 0.0043
# Epoch 55/100
# 24/24 [==============================] - 3s 129ms/step - loss: 0.0047
# Epoch 56/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0037
# Epoch 57/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0041
# Epoch 58/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0042
# Epoch 59/100
# 24/24 [==============================] - 3s 127ms/step - loss: 0.0040
# Epoch 60/100
# 24/24 [==============================] - 3s 129ms/step - loss: 0.0043
# Epoch 61/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0054
# Epoch 62/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0042
# Epoch 63/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0042
# Epoch 64/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0039
# Epoch 65/100
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0039
# Epoch 66/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0042
# Epoch 67/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0033
# Epoch 68/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0038
# Epoch 69/100
# 24/24 [==============================] - 3s 127ms/step - loss: 0.0038
# Epoch 70/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0036
# Epoch 71/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0037
# Epoch 72/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0040
# Epoch 73/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0037
# Epoch 74/100
# 24/24 [==============================] - 3s 129ms/step - loss: 0.0035
# Epoch 75/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0037
# Epoch 76/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0037
# Epoch 77/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0036
# Epoch 78/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0033
# Epoch 79/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0034
# Epoch 80/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0037
# Epoch 81/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0036
# Epoch 82/100
# 24/24 [==============================] - 3s 127ms/step - loss: 0.0034
# Epoch 83/100
# 24/24 [==============================] - 4s 159ms/step - loss: 0.0029
# Epoch 84/100
# 24/24 [==============================] - 4s 159ms/step - loss: 0.0038
# Epoch 85/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0033
# Epoch 86/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0035
# Epoch 87/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0029
# Epoch 88/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0032
# Epoch 89/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0031
# Epoch 90/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0035
# Epoch 91/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0032
# Epoch 92/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0029
# Epoch 93/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0031
# Epoch 94/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0030
# Epoch 95/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0029
# Epoch 96/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0029
# Epoch 97/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0030
# Epoch 98/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0028
# Epoch 99/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0026
# Epoch 100/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0030

# %% [markdown]
# ## Prepare the test data (reshape them):

# %%
# Getting the predicted stock price of 2017
dataset_train = df.iloc[:800, 1:2]
dataset_test = df.iloc[800:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 588):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# (528, 60, 1)
# Out:
# (528, 60, 1)

# %% [markdown]
# ## Make Predictions using the test set

# %%
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %% [markdown]
# ## Visualize the results

# %%
# Visualising the results
plt.plot(df.loc[800:, 'Date'],dataset_test.values, color = 'red', label = 'Real TESLA Stock Price' )
plt.plot(df.loc[800:, 'Date'],predicted_stock_price, color = 'blue', label = 'Predicted TESLA Stock Price')
plt.xticks(np.arange(0,528,50))
plt.title('TESLA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TESLA Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# # 2. Change to Lag7

# %%
# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(60, 800,7):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
print(X_train.shape)
# Out:
# (106, 60, 1)

# %%
model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 78ms/step - loss: 0.2228
# Epoch 2/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0410
# Epoch 3/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0224
# Epoch 4/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0317
# Epoch 5/100
# 4/4 [==============================] - 0s 84ms/step - loss: 0.0166
# Epoch 6/100
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0240
# Epoch 7/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0197
# Epoch 8/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0128
# Epoch 9/100
# 4/4 [==============================] - 0s 88ms/step - loss: 0.0141
# Epoch 10/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0109
# Epoch 11/100
# 4/4 [==============================] - 0s 88ms/step - loss: 0.0122
# Epoch 12/100
# 4/4 [==============================] - 0s 92ms/step - loss: 0.0113
# Epoch 13/100
# 4/4 [==============================] - 0s 92ms/step - loss: 0.0135
# Epoch 14/100
# 4/4 [==============================] - 0s 85ms/step - loss: 0.0094
# Epoch 15/100
# 4/4 [==============================] - 0s 84ms/step - loss: 0.0107
# Epoch 16/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0093
# Epoch 17/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0097
# Epoch 18/100
# Epoch 93/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0084
# Epoch 94/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0079
# Epoch 95/100
# 4/4 [==============================] - 0s 85ms/step - loss: 0.0077
# Epoch 96/100
# 4/4 [==============================] - 0s 91ms/step - loss: 0.0081
# Epoch 97/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0090
# Epoch 98/100
# 4/4 [==============================] - 0s 90ms/step - loss: 0.0078
# Epoch 99/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0065
# Epoch 100/100
# 4/4 [==============================] - 0s 97ms/step - loss: 0.0077

# %%
dataset_train = df.iloc[:800, 1:2]
dataset_test = df.iloc[800:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 588):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# Out:
# (528, 60, 1)

# %%
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
# Visualising the results
plt.plot(df.loc[800:, 'Date'],dataset_test.values, color = 'red', label = 'Real TESLA Stock Price' )
plt.plot(df.loc[800:, 'Date'],predicted_stock_price, color = 'blue', label = 'Predicted TESLA Stock Price')
plt.xticks(np.arange(0,528,50))
plt.title('TESLA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TESLA Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# # 3. Change to Lag14

# %%
# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(60, 800, 14):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
print(X_train.shape)
# Out:
# (53, 60, 1)

# %%
model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.3229
# Epoch 2/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.2159
# Epoch 3/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0920
# Epoch 4/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0398
# Epoch 5/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0721
# Epoch 6/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0229
# Epoch 7/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0321
# Epoch 8/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0544
# Epoch 9/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0370
# Epoch 10/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0308
# Epoch 11/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0201
# Epoch 12/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0214
# Epoch 13/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0280
# Epoch 14/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0203
# Epoch 15/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0165
# Epoch 16/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0173
# Epoch 17/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0184
# Epoch 18/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0178
# Epoch 19/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0135
# Epoch 20/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0131
# Epoch 21/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0139
# Epoch 22/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0113
# Epoch 23/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0124
# Epoch 24/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0135
# Epoch 25/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0158
# Epoch 26/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0112
# Epoch 27/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0133
# Epoch 28/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0129
# Epoch 29/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0121
# Epoch 30/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0132
# Epoch 31/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0135
# Epoch 32/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0129
# Epoch 33/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0085
# Epoch 34/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0089
# Epoch 35/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0119
# Epoch 36/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0112
# Epoch 37/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0118
# Epoch 38/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0143
# Epoch 39/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0123
# Epoch 40/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0107
# Epoch 41/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0116
# Epoch 42/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0092
# Epoch 43/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0097
# Epoch 44/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0086
# Epoch 45/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0087
# Epoch 46/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0089
# Epoch 47/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0067
# Epoch 48/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0117
# Epoch 49/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0111
# Epoch 50/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0085
# Epoch 51/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0104
# Epoch 52/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0085
# Epoch 53/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0096
# Epoch 54/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0088
# Epoch 55/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0068
# Epoch 56/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0059
# Epoch 57/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0100
# Epoch 58/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0090
# Epoch 59/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0070
# Epoch 60/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0081
# Epoch 61/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0092
# Epoch 62/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0082
# Epoch 63/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0119
# Epoch 64/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0078
# Epoch 65/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0124
# Epoch 66/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0090
# Epoch 67/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0074
# Epoch 68/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0073
# Epoch 69/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0108
# Epoch 70/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0112
# Epoch 71/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0127
# Epoch 72/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0074
# Epoch 73/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0102
# Epoch 74/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0088
# Epoch 75/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0101
# Epoch 76/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0089
# Epoch 77/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0089
# Epoch 78/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0084
# Epoch 79/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0097
# Epoch 80/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0088
# Epoch 81/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0106
# Epoch 82/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0070
# Epoch 83/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0103
# Epoch 84/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0102
# Epoch 85/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0099
# Epoch 86/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0082
# Epoch 87/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0113
# Epoch 88/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0109
# Epoch 89/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0092
# Epoch 90/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0083
# Epoch 91/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0108
# Epoch 92/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0064
# Epoch 93/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0067
# Epoch 94/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0067
# Epoch 95/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0091
# Epoch 96/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0121
# Epoch 97/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0070
# Epoch 98/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0099
# Epoch 99/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0086
# Epoch 100/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0077

# %%
dataset_train = df.iloc[:800, 1:2]
dataset_test = df.iloc[800:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 588):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# Out:
# (528, 60, 1)

# %%
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
# Visualising the results
plt.plot(df.loc[800:, 'Date'],dataset_test.values, color = 'red', label = 'Real TESLA Stock Price' )
plt.plot(df.loc[800:, 'Date'],predicted_stock_price, color = 'blue', label = 'Predicted TESLA Stock Price')
plt.xticks(np.arange(0,528,50))
plt.title('TESLA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TESLA Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# # 4. Two Comparisons: Compare with 4 hidden layers and 6 hidden layers & Compare with 32 batch size with 64 batch size

# %%
# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(60, 800):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
print(X_train.shape)
# Out:
# (740, 60, 1)

# %%
model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

# %%
model1 = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model1.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50, return_sequences = True))
model1.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50, return_sequences = True))
model1.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50, return_sequences = True))
model1.add(Dropout(0.2))
# Adding a fifth LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50, return_sequences = True))
model1.add(Dropout(0.2))
# Adding a sixth LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50))
model1.add(Dropout(0.2))
# Adding the output layer
model1.add(Dense(units = 1))

# %%
model2 = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model2.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model2.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model2.add(LSTM(units = 50, return_sequences = True))
model2.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model2.add(LSTM(units = 50, return_sequences = True))
model2.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model2.add(LSTM(units = 50))
model2.add(Dropout(0.2))
# Adding the output layer
model2.add(Dense(units = 1))

# %%
# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model1.compile(optimizer = 'adam', loss = 'mean_squared_error')
model2.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
model1.fit(X_train, y_train, epochs = 100, batch_size = 32)
model2.fit(X_train, y_train, epochs = 100, batch_size = 64)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0715
# Epoch 2/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0173
# Epoch 3/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0132
# Epoch 4/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0135
# Epoch 5/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0122
# Epoch 6/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0116
# Epoch 7/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0107
# Epoch 8/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0105
# Epoch 9/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0117
# Epoch 10/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0114
# Epoch 11/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0111
# Epoch 12/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0098
# Epoch 13/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0091
# Epoch 14/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0083
# Epoch 15/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0091
# Epoch 16/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0083
# Epoch 17/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0076
# Epoch 18/100
# 24/24 [==============================] - 3s 138ms/step - loss: 0.0073
# Epoch 19/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0074
# Epoch 20/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0069
# Epoch 21/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0069
# Epoch 22/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0065
# Epoch 23/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0061
# Epoch 24/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0066
# Epoch 25/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0072
# Epoch 26/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0073
# Epoch 27/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0065
# Epoch 28/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0069
# Epoch 29/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0065
# Epoch 30/100
# 24/24 [==============================] - 3s 126ms/step - loss: 0.0057
# Epoch 31/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0071
# Epoch 32/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0063
# Epoch 33/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0069
# Epoch 34/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0051
# Epoch 35/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0055
# Epoch 36/100
# 24/24 [==============================] - 3s 126ms/step - loss: 0.0056
# Epoch 37/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0050
# Epoch 38/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0051
# Epoch 39/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0046
# Epoch 40/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0050
# Epoch 41/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0056
# Epoch 42/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0046
# Epoch 43/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0047
# Epoch 44/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0051
# Epoch 45/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0046
# Epoch 46/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0051
# Epoch 47/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0044
# Epoch 48/100
# 24/24 [==============================] - 3s 128ms/step - loss: 0.0043
# Epoch 49/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0043
# Epoch 50/100
# 24/24 [==============================] - 3s 126ms/step - loss: 0.0045
# Epoch 51/100
# 24/24 [==============================] - 4s 163ms/step - loss: 0.0042
# Epoch 52/100
# 24/24 [==============================] - 4s 160ms/step - loss: 0.0048
# Epoch 53/100
# 24/24 [==============================] - 3s 145ms/step - loss: 0.0040
# Epoch 54/100
# 24/24 [==============================] - 3s 128ms/step - loss: 0.0041
# Epoch 55/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0040
# Epoch 56/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0043
# Epoch 57/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0051
# Epoch 58/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0048
# Epoch 59/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0041
# Epoch 60/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0040
# Epoch 61/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0034
# Epoch 62/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0041
# Epoch 63/100
# 24/24 [==============================] - 3s 128ms/step - loss: 0.0038
# Epoch 64/100
# 24/24 [==============================] - 3s 127ms/step - loss: 0.0038
# Epoch 65/100
# 24/24 [==============================] - 3s 126ms/step - loss: 0.0041
# Epoch 66/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0037
# Epoch 67/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0033
# Epoch 68/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0034
# Epoch 69/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0035
# Epoch 70/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0038
# Epoch 71/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0039
# Epoch 72/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0036
# Epoch 73/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0037
# Epoch 74/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0040
# Epoch 75/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0035
# Epoch 76/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0034
# Epoch 77/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0034
# Epoch 78/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0035
# Epoch 79/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0031
# Epoch 80/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0034
# Epoch 81/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0036
# Epoch 82/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0035
# Epoch 83/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0035
# Epoch 84/100
# 24/24 [==============================] - 3s 127ms/step - loss: 0.0031
# Epoch 85/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0032
# Epoch 86/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0029
# Epoch 87/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0026
# Epoch 88/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0032
# Epoch 89/100
# 24/24 [==============================] - 3s 127ms/step - loss: 0.0028
# Epoch 90/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0037
# Epoch 91/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0031
# Epoch 92/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0031
# Epoch 93/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0027
# Epoch 94/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0033
# Epoch 95/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0031
# Epoch 96/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0031
# Epoch 97/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0031
# Epoch 98/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0028
# Epoch 99/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0031
# Epoch 100/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0027
# Epoch 1/100
# 12/12 [==============================] - 2s 146ms/step - loss: 0.0042
# Epoch 89/100
# 12/12 [==============================] - 2s 142ms/step - loss: 0.0041
# Epoch 90/100
# 12/12 [==============================] - 2s 141ms/step - loss: 0.0042
# Epoch 91/100
# 12/12 [==============================] - 2s 142ms/step - loss: 0.0041
# Epoch 92/100
# 12/12 [==============================] - 2s 142ms/step - loss: 0.0040
# Epoch 93/100
# 12/12 [==============================] - 2s 138ms/step - loss: 0.0039
# Epoch 94/100
# 12/12 [==============================] - 2s 143ms/step - loss: 0.0043
# Epoch 95/100
# 12/12 [==============================] - 2s 144ms/step - loss: 0.0043
# Epoch 96/100
# 12/12 [==============================] - 2s 139ms/step - loss: 0.0039
# Epoch 97/100
# 12/12 [==============================] - 2s 138ms/step - loss: 0.0042
# Epoch 98/100
# 12/12 [==============================] - 2s 145ms/step - loss: 0.0039
# Epoch 99/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0040
# Epoch 100/100
# 12/12 [==============================] - 2s 200ms/step - loss: 0.0041

# %%
dataset_train = df.iloc[:800, 1:2]
dataset_test = df.iloc[800:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 588):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# Out:
# (528, 60, 1)

# %%
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
predicted_stock_price1 = model1.predict(X_test)
predicted_stock_price1 = sc.inverse_transform(predicted_stock_price1)
predicted_stock_price2 = model2.predict(X_test)
predicted_stock_price2 = sc.inverse_transform(predicted_stock_price2)

# %%
# Visualising the results
plt.plot(df.loc[800:, 'Date'],dataset_test.values, color = 'red', label = 'Real TESLA Stock Price')
a = df.loc[800:,'Date']
plt.plot(df.loc[800:, 'Date'],predicted_stock_price, color = 'blue', label = 'Predicted TESLA Stock Price with orgin')
plt.plot(df.loc[800:, 'Date'],predicted_stock_price1, color = 'green', label = 'Predicted TESLA Stock Price with 6 hidden layers')
plt.plot(df.loc[800:, 'Date'],predicted_stock_price2, color = 'yellow', label = 'Predicted TESLA Stock Price with 64 batch size')
plt.xticks(np.arange(0,528,50))
plt.title('TESLA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TESLA Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# # 5. make predictions for future two weeks, until Oct 28, 2020

# %%
import copy
X_test2 = copy.deepcopy(X_test)
for i in range(14):
    X_temp = np.zeros([1,60,1])
    for j in range(58):
        X_temp[0][j][0]= X_test[-1][j+1][0]
    X_temp[0][59][0] = model.predict(X_test2[-1:])[0][0]
    X_test2 = np.vstack([X_test2,X_temp])

predicted_stock_price = model.predict(X_test2)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
predicted_stock_price.shape
# Out:
# (542, 1)

# %%
c = ["2020/10/14","2020/10/15","2020/10/16","2020/10/17","2020/10/18","2020/10/19","2020/10/20","2020/10/21","2020/10/22","2020/10/23","2020/10/24","2020/10/25","2020/10/26","2020/10/27","2020/10/28"]
plt.plot(c,predicted_stock_price[527:], color = 'blue', label = 'Predicted TESLA Stock Price')
plt.title('TESLA Stock Price Prediction')
plt.xticks(np.arange(0,14,3))
plt.xlabel('Time')
plt.ylabel('TESLA Stock Price')
plt.legend()
plt.show()
